# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from pandas.plotting import register_matplotlib_converters
register_matplotlib_converters()

# %%
df = pd.read_csv('mushroom_data_all.csv')

# %%
df.head(5)
# Out:
#   class_edible cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0            p         x           s         n       t    p               f
# 1            e         x           s         y       t    a               f
# 2            e         b           s         w       t    l               f
# 3            p         x           y         w       t    p               f
# 4            e         x           s         g       f    n               f
#
#   gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# 0            c         n          k  ...                        s
# 1            c         b          k  ...                        s
# 2            c         b          n  ...                        s
# 3            c         n          n  ...                        s
# 4            w         b          k  ...                        s
#
#   stalk-color-above-ring stalk-color-below-ring veil-type veil-color  \
# ...

# %%
nan_exist = df.isna().any().any()
print(f"Are there any NaN values in the dataset? {nan_exist}")
# Out:
# Are there any NaN values in the dataset? False

# %%
unique_values_count = df['cap-shape'].nunique()

print("Number of unique values in 'cap-shape':", unique_values_count)
# Out:
# Number of unique values in 'cap-shape': 6

# %%
unique_values_count = df['cap-surface'].nunique()

print("Number of unique values in 'cap-surface':", unique_values_count)
# Out:
# Number of unique values in 'cap-surface': 4

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder

# Assuming df is your DataFrame containing the 23 categorical columns

label_encoders = {}

for col in df.columns:
    if df[col].dtype == 'object':  # Check if the column is categorical
        label_encoders[col] = LabelEncoder()  # Initialize LabelEncoder for the column
        df[col] = label_encoders[col].fit_transform(df[col])  # Apply label encoding to the column
df
# Out:
#       class_edible  cap-shape  cap-surface  cap-color  bruises  odor  \
# 0                1          5            2          4        1     6
# 1                0          5            2          9        1     0
# 2                0          0            2          8        1     3
# 3                1          5            3          8        1     6
# 4                0          5            2          3        0     5
# ...            ...        ...          ...        ...      ...   ...
# 8119             0          3            2          4        0     5
# 8120             0          5            2          4        0     5
# 8121             0          2            2          4        0     5
# 8122             1          3            3          4        0     8
# 8123             0          5            2          4        0     5
#
#       gill-attachment  gill-spacing  gill-size  gill-color  ...  \
# 0                   1             0          1           4  ...
# ...

# %%
df.head(5)
# Out:
#    class_edible  cap-shape  cap-surface  cap-color  bruises  odor  \
# 0             1          5            2          4        1     6
# 1             0          5            2          9        1     0
# 2             0          0            2          8        1     3
# 3             1          5            3          8        1     6
# 4             0          5            2          3        0     5
#
#    gill-attachment  gill-spacing  gill-size  gill-color  ...  \
# 0                1             0          1           4  ...
# 1                1             0          0           4  ...
# 2                1             0          0           5  ...
# 3                1             0          1           5  ...
# 4                1             1          0           4  ...
#
#    stalk-surface-below-ring  stalk-color-above-ring  stalk-color-below-ring  \
# 0                         2                       7                       7
# ...

# %%
# import pandas as pd

# # Assuming df is your DataFrame containing the 23 categorical columns

# # List to store the DataFrames after one-hot encoding each column
# one_hot_encoded_dfs = []

# for col in df.columns:
#     if df[col].dtype == 'object':  # Check if the column is categorical
#         one_hot_encoded = pd.get_dummies(df[col], prefix=col)  # Perform one-hot encoding
#         one_hot_encoded_dfs.append(one_hot_encoded)

# # Concatenate all the one-hot encoded DataFrames along the columns axis
# df_encoded = pd.concat([df] + one_hot_encoded_dfs, axis=1)

# # Drop the original categorical columns
# df_encoded = df_encoded.drop(df.columns, axis=1)

# %% [markdown]
# ### Split Train and Test

# %%
columns = ['class_edible', 'cap-shape', 'cap-surface', 'cap-color', 'bruises',
       'odor', 'gill-attachment', 'gill-spacing', 'gill-size', 'gill-color',
       'stalk-shape', 'stalk-root', 'stalk-surface-above-ring',
       'stalk-surface-below-ring', 'stalk-color-above-ring',
       'stalk-color-below-ring', 'veil-type', 'veil-color', 'ring-number',
       'ring-type', 'spore-print-color', 'population', 'habitat']

# %%
# Training = 70% of the data
# Validation = 30% of the data
# Randomize the datset
np.random.seed(5)
l = list(df.index)
np.random.shuffle(l)
df = df.iloc[l]

# %%
rows = df.shape[0]
train = int(.7 * rows)
test = rows-train

# %%
rows, train, test
# Out:
# (8124, 5686, 2438)

# %%
# Write Training Set
df[:train].to_csv('mushroom_train.csv'
                          ,index=False,header=False
                          ,columns=columns)

# %%
# Write Validation Set
df[train:].to_csv('mushroom_validation.csv'
                          ,index=False,header=False
                          ,columns=columns)

# %%
# Write Column List
with open('mushroom_train_column_list.txt','w') as f:
    f.write(','.join(columns))

# %% [markdown]
# ### Training

# %%
# !pip install xgboost
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 297.1/297.1 MB 2.7 MB/s eta 0:00:00:00:0100:01
# ...

# %%
import sys
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import itertools
import xgboost as xgb

from sklearn import preprocessing
from sklearn.metrics import classification_report, confusion_matrix

# %%
column_list_file = 'mushroom_train_column_list.txt'
train_file = 'mushroom_train.csv'
validation_file = 'mushroom_validation.csv'

# %%
columns = ''
with open(column_list_file,'r') as f:
    columns = f.read().split(',')

# %%
# Specify the column names as the file does not have column header
df_train = pd.read_csv(train_file,names=columns)
df_validation = pd.read_csv(validation_file,names=columns)

# %%
df_train.head(5)
# Out:
#    class_edible  cap-shape  cap-surface  cap-color  bruises  odor  \
# 0             1          5            2          0        1     2
# 1             1          3            3          4        0     7
# 2             1          2            3          9        0     2
# 3             0          0            3          8        1     0
# 4             0          5            3          2        1     5
#
#    gill-attachment  gill-spacing  gill-size  gill-color  ...  \
# 0                1             0          0           3  ...
# 1                1             0          1           0  ...
# 2                1             0          0           2  ...
# 3                1             0          0          10  ...
# 4                1             0          0           7  ...
#
#    stalk-surface-below-ring  stalk-color-above-ring  stalk-color-below-ring  \
# 0                         0                       7                       7
# ...

# %%
df_validation.head(5)
# Out:
#    class_edible  cap-shape  cap-surface  cap-color  bruises  odor  \
# 0             0          2            0          8        0     5
# 1             0          5            2          3        0     5
# 2             0          5            0          8        0     5
# 3             0          5            2          4        0     5
# 4             0          5            3          3        1     5
#
#    gill-attachment  gill-spacing  gill-size  gill-color  ...  \
# 0                1             1          0           7  ...
# 1                1             1          0           5  ...
# 2                1             1          0           4  ...
# 3                0             0          0           5  ...
# 4                1             0          0           5  ...
#
#    stalk-surface-below-ring  stalk-color-above-ring  stalk-color-below-ring  \
# 0                         2                       7                       7
# ...

# %%
X_train = df_train.iloc[:,1:] # Features: 1st column onwards 
y_train = df_train.iloc[:,0].ravel() # Target: 0th column

X_validation = df_validation.iloc[:,1:]
y_validation = df_validation.iloc[:,0].ravel()
# Out:
# /tmp/ipykernel_7677/2629520565.py:2: FutureWarning: Series.ravel is deprecated. The underlying array is already 1D, so ravel is not necessary.  Use `to_numpy()` for conversion to a numpy array instead.
#   y_train = df_train.iloc[:,0].ravel() # Target: 0th column
# /tmp/ipykernel_7677/2629520565.py:5: FutureWarning: Series.ravel is deprecated. The underlying array is already 1D, so ravel is not necessary.  Use `to_numpy()` for conversion to a numpy array instead.
#   y_validation = df_validation.iloc[:,0].ravel()

# %%
classifier = xgb.XGBClassifier(objective="binary:logistic",
                               )

# %%
classifier.fit(X_train,
               y_train,
               eval_set = [(X_train, y_train), (X_validation, y_validation)],
               eval_metric=['logloss'],
               early_stopping_rounds=10)
# Out:
# [0]	validation_0-logloss:0.44327	validation_1-logloss:0.44409
# [1]	validation_0-logloss:0.30507	validation_1-logloss:0.30616
# [2]	validation_0-logloss:0.21422	validation_1-logloss:0.21524
# [3]	validation_0-logloss:0.15365	validation_1-logloss:0.15443
# [4]	validation_0-logloss:0.11180	validation_1-logloss:0.11266
# [5]	validation_0-logloss:0.08226	validation_1-logloss:0.08322
# [6]	validation_0-logloss:0.06124	validation_1-logloss:0.06202
# [7]	validation_0-logloss:0.04600	validation_1-logloss:0.04662
# [8]	validation_0-logloss:0.03460	validation_1-logloss:0.03510
# [9]	validation_0-logloss:0.02632	validation_1-logloss:0.02686
# [10]	validation_0-logloss:0.02020	validation_1-logloss:0.02067
# [11]	validation_0-logloss:0.01521	validation_1-logloss:0.01557
# [12]	validation_0-logloss:0.01153	validation_1-logloss:0.01181
# [13]	validation_0-logloss:0.00887	validation_1-logloss:0.00908
# [14]	validation_0-logloss:0.00732	validation_1-logloss:0.00752
# ...

# %%
print(X_train.shape)
print(y_train.shape)
print(X_validation.shape)
print(y_validation.shape)
# Out:
# (5686, 22)
# (5686,)
# (2438, 22)
# (2438,)

# %%
eval_result = classifier.evals_result()

# %%
training_rounds = range(len(eval_result['validation_0']['logloss']))

# %%
print(training_rounds)
# Out:
# range(0, 100)

# %%
plt.scatter(x=training_rounds,y=eval_result['validation_0']['logloss'],label='Training Error')
plt.scatter(x=training_rounds,y=eval_result['validation_1']['logloss'],label='Validation Error')
plt.grid(True)
plt.xlabel('Iteration')
plt.ylabel('LogLoss')
plt.title('Training Vs Validation Error')
plt.legend()
plt.show()

# %%
xgb.plot_importance(classifier)
plt.show()

# %%
df = pd.read_csv(validation_file,names=columns)
df.head(5)
# Out:
#    class_edible  cap-shape  cap-surface  cap-color  bruises  odor  \
# 0             0          2            0          8        0     5
# 1             0          5            2          3        0     5
# 2             0          5            0          8        0     5
# 3             0          5            2          4        0     5
# 4             0          5            3          3        1     5
#
#    gill-attachment  gill-spacing  gill-size  gill-color  ...  \
# 0                1             1          0           7  ...
# 1                1             1          0           5  ...
# 2                1             1          0           4  ...
# 3                0             0          0           5  ...
# 4                1             0          0           5  ...
#
#    stalk-surface-below-ring  stalk-color-above-ring  stalk-color-below-ring  \
# 0                         2                       7                       7
# ...

# %%
X_test = df.iloc[:,1:]
print(X_test[:5])
# Out:
#    cap-shape  cap-surface  cap-color  bruises  odor  gill-attachment  \
# 0          2            0          8        0     5                1
# 1          5            2          3        0     5                1
# 2          5            0          8        0     5                1
# 3          5            2          4        0     5                0
# 4          5            3          3        1     5                1
#
#    gill-spacing  gill-size  gill-color  stalk-shape  ...  \
# 0             1          0           7            1  ...
# 1             1          0           5            1  ...
# 2             1          0           4            1  ...
# 3             0          0           5            0  ...
# 4             0          0           5            1  ...
#
#    stalk-surface-below-ring  stalk-color-above-ring  stalk-color-below-ring  \
# 0                         2                       7                       7
# ...

# %%
result = classifier.predict(X_test)

# %%
df['predicted_class'] = result #le.inverse_transform(result)

# %%
df.head(5)
# Out:
#    class_edible  cap-shape  cap-surface  cap-color  bruises  odor  \
# 0             0          2            0          8        0     5
# 1             0          5            2          3        0     5
# 2             0          5            0          8        0     5
# 3             0          5            2          4        0     5
# 4             0          5            3          3        1     5
#
#    gill-attachment  gill-spacing  gill-size  gill-color  ...  \
# 0                1             1          0           7  ...
# 1                1             1          0           5  ...
# 2                1             1          0           4  ...
# 3                0             0          0           5  ...
# 4                1             0          0           5  ...
#
#    stalk-color-above-ring  stalk-color-below-ring  veil-type  veil-color  \
# 0                       7                       7          0           2
# ...

# %%
df.class_edible.value_counts()
# Out:
# class_edible
# 0    1243
# 1    1195
# Name: count, dtype: int64

# %%
df.predicted_class.value_counts()
# Out:
# predicted_class
# 0    1243
# 1    1195
# Name: count, dtype: int64
